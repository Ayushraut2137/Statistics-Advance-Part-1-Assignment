# %% [markdown]
# # Statistics Advance Part 1 Assignment

# %% [markdown]
# 1. What is a random variable in probability theory?
# --> a random variable is a function that assigns a numerical value to each outcome in a sample space of a random experiment.
#
# Types of Random Variables:
#
# a. Discrete Random Variable :
#
# Takes on a countable number of possible values.
#
# Example: Number of heads in 3 coin tosses (can be 0, 1, 2, or 3).
#
# b. Continuous Random Variable:
#
# Takes on values from an uncountably infinite set (like all real numbers in an interval).
#
# 2. What are the types of random variables?
# --> a. Discrete Random Variable :
#
# Takes on a countable number of possible values.
#
# Example: Number of heads in 3 coin tosses (can be 0, 1, 2, or 3).
#
# b. Continuous Random Variable:
#
# Takes on values from an uncountably infinite set (like all real numbers in an interval).
#
# Often arises from measuring (e.g., time, height, weight, temperature)
#
# 3. What is the difference between discrete and continuous distributions?
# --> a. Discrete distributions:
#
# Takes countable values (finite or countably infinite).
#
# Specific, separate values (e.g., 0, 1, 2, 3...).
#
# P(X=x) can be positive.
#
# Uses Probability Mass Function (PMF).
#
# Probability is Measured By summing probabilities of individual outcomes.
#
# Examples: Number of students in a class, rolling a die.
#
# b. Continuous distribution:
#
# Takes uncountable values (infinitely many within any interval).
#
# Nature of Values- Any real number within an interval (e.g., 2.5, 3.01, π...).
#
# Uses Probability Density Function (PDF).
#
# Probability is Measured By integrating the PDF over an interval.
#
# example - Height of a person, time to run a race.
#
# 4. What are probability distribution functions (PDF)?
# --> a Probability Distribution Function (PDF) refers to a function that describes the likelihood of a continuous random variable taking on a particular value.
#
# 5. How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?
# --> a.Probability Density Function (PDF):
#
# Describes the relative likelihood of a random variable taking a specific value (used for continuous variables).
#
# Notation - f(x)
#
# Values Represent- Density, not actual probability.
#
# Shape - May have peaks or curves depending on distribution.
#
# b. Cumulative Distribution Function (CDF):
#
# Describes the cumulative probability that a random variable is less than or equal to a value.
#
# Notation - F(x)
#
# Values Representation - actual probability
#
# shape - Always a non-decreasing, smooth, S-shaped (for continuous variables) function.
#
# 6. What is a discrete uniform distribution?
# --> A discrete uniform distribution is a type of probability distribution where all outcomes are equally likely and come from a finite set of distinct values.
#
#
# 7. What are the key properties of a Bernoulli distribution?
# --> Properties of Bernoulli Distribution:
#
# Type of Distribution - Discrete
#
# Parameter - p
#
# Used to model yes/no, success/failure, pass/fail type experiments.
#
# The Bernoulli distribution is a special case of the binomial distribution where the number of trials n = 1.
#
# 8.  What is the binomial distribution, and how is it used in probability?
# --> The binomial distribution is a discrete probability distribution that models the number of successes in a fixed number of independent trials, where each trial has only two outcomes: success or failure.
#
# The binomial distribution is used to calculate the probability of getting a certain number of successes in multiple repeated trials, where:
#
# Each trial is independent,
#
# Each trial has the same probability of success,
#
# There are a fixed number of trials.
#
# 9. What is the Poisson distribution and where is it applied?
# --> The Poisson distribution is a discrete probability distribution that models the number of times an event occurs in a fixed interval of time or space, given that the events occur independently and at a constant average rate.
#
# The Poisson distribution is used when we are interested in the number of occurrences of an event in a given interval (of time, area, volume, etc.), especially when:
#
#  Events occur independently
#
#  Events occur at a constant average rate
#
#  Two events cannot occur at exactly the same instant
#
# 10. What is a continuous uniform distribution?
# --> The continuous uniform distribution is a continuous probability distribution where all values within a specified interval are equally likely to occur.
#
# It is the continuous version of the discrete uniform distribution.
#
# 11. What are the characteristics of a normal distribution?
# -->Characteristics of normal distribution:
#
# a. Bell-shaped Curve -
#
# The graph of a normal distribution is symmetrical and has a bell-shaped curve.
#
# Most values cluster around the mean.
#
# b. Symmetry about the Mean
#
# The distribution is perfectly symmetric about the mean 𝜇
#
# c. Mean = Median = Mode
#
# In a normal distribution, all three measures of central tendency are equal and located at the center of the distribution.
#
# d. Defined by Two Parameters
#
# Mean (𝜇): Determines the location (center) of the distribution.
#
# Standard deviation (𝜎): Determines the spread (width) of the distribution.
#
# e. Asymptotic
#
# The tails of the curve extend infinitely in both directions and never touch the x-axis.
#
# f. Unimodal
#
# The distribution has only one peak (mode).
#
# g. Area Under the Curve = 1
#
# The total probability represented by the curve is 1, which corresponds to all possible values of the random variable.
#
# 12. What is the standard normal distribution, and why is it important?
# --> The Standard Normal Distribution is a special case of the normal distribution where:
#
# Mean 𝜇=0
#
# Standard deviation 𝜎=1
#
# It is used to standardize normal distributions so that they can be compared and analyzed using a common scale.
#
# Importance of standard normal distribution
#
# a. Universal Reference
#
# Makes different normal distributions comparable by converting them to the same scale.
#
# b. Z-tables and Probability Calculation
#
# Helps find probabilities and critical values using standard normal (Z) tables.
#
# c. Statistical Inference
#
# Used in confidence intervals, hypothesis testing, and regression analysis.
#
# d. Based on the Central Limit Theorem
#
# The CLT states that, regardless of the population distribution, the sample mean tends to be normally distributed for large sample sizes, which makes the standard normal distribution very useful.
#
# 13. What is the Central Limit Theorem (CLT), and why is it critical in statistics?
# --> The Central Limit Theorem (CLT) is a fundamental concept in statistics that explains the behavior of sampling distributions.
#
# a. Applies to Sample Means
#
# The CLT describes the distribution of the sample mean 𝑋, not individual data points.
#
# b. Population Can Be Any Distribution
#
# The original population can be normal, skewed, uniform, or any other distribution.
#
# c. Sample Size Should Be Large Enough
#
# The larger the sample size 𝑛, the more closely the distribution of x resembles a normal distribution.
#
# d. Foundation for Inferential Statistics
#
# CLT allows us to make predictions and generalizations about populations based on sample data.
#
# e. Enables Confidence Intervals
#
# We can construct confidence intervals for population parameters using sample means.
#
# f. Supports Hypothesis Testing
#
# CLT justifies the use of z-tests and t-tests even when the population is not normally distributed.
#
# 14.  How does the Central Limit Theorem relate to the normal distribution?
# --> The Central Limit Theorem (CLT) is directly connected to the normal distribution because it explains why and when we can use the normal distribution to approximate other distributions — even when the original data is not normally distributed.
#
# 15. What is the application of Z statistics in hypothesis testing?
# --> Z-statistics are used in hypothesis testing when we want to determine whether a sample mean or proportion significantly differs from a population mean or proportion — assuming the population standard deviation is known.
#
# Applications of Z statistics in hypothesis testing -
#
# Testing whether a new teaching method changes test scores
#
# Checking if a factory’s production mean is as claimed
#
# Determining if a website conversion rate differs from the historical average
#
# Comparing results from polls to known population percentages
#
# 16.  How do you calculate a Z-score, and what does it represent?
# --> A Z-score (also called a standard score) tells you how many standard deviations a data point is from the mean of a distribution.
#
# Z-score Formula-
#
# 𝑍=𝑋−𝜇/𝜎
#
# Where:
#
# 𝑋 = individual data point
#
# 𝜇 = population mean
#
# 𝜎 = population standard deviation
#
# A Z-score indicates the relative position of a value within a distribution.
#
# It tells you how unusual or typical a value is compared to the rest of the data.
#
#
# 17. What are point estimates and interval estimates in statistics?
# --> a. Point Estimate:
#
# A point estimate is a single value used to approximate a population parameter.
#
# Characteristics:
#
# Simple and quick
#
# Does not reflect uncertainty
#
# Used as a best guess of the parameter
#
# b. Interval Estimate:
#
# An interval estimate gives a range of values (an interval) within which the population parameter is likely to fall.
#
# It is usually expressed as a confidence interval.
#
# Characteristics:
#
# Reflects uncertainty and variability
#
# The level of confidence (e.g., 95%, 99%) shows how sure we are that the interval contains the parameter
#
# More informative than point estimates
#
# 18. What is the significance of confidence intervals in statistical analysis?
# --> Confidence intervals (CIs) are essential tools in statistics that provide a range of plausible values for an unknown population parameter (such as the mean or proportion). They give us a sense of precision and reliability in our estimates based on sample data.
#
# Significance of Confidence Intervals:
#
# a. Estimates Population Parameters More Reliably
#
# A confidence interval provides a range, not just a single point, within which the true population parameter is likely to lie.
#
# It’s more informative than a point estimate because it reflects sampling variability.
#
# b. Accounts for Sampling Error
#
# Since sample data can vary, confidence intervals help quantify the uncertainty that comes with using a sample to estimate a population parameter.
#
# c. Used in Hypothesis Testing
#
# If the hypothesized value (like a population mean) falls outside the confidence interval, we may reject the null hypothesis
#
# d. Reflects Confidence Level
#
# A 95% confidence interval means that if we repeated the sampling process many times, about 95% of the calculated intervals would contain the true parameter.
#
# Common confidence levels: 90%, 95%, 99%
#
# e. Guides Decision-Making
#
# Widely used in fields like business, medicine, and research to make informed decisions based on data.
#
# 19. What is the relationship between a Z-score and a confidence interval?
# --> The Z-score and the confidence interval (CI) are closely related in statistics — particularly when estimating population parameters like the mean or proportion. The Z-score is used to construct the confidence interval by determining the margin of error.
#
# a. Z-score -
#
# Measures distance in standard deviations
#
# Used to calculate the margin of error
#
# b. Confidence Interval-
#
# Estimates range for population parameter
#
# Built using Z-score and standard error
#
# 20. How are Z-scores used to compare different distributions?
# --> a. Z-score Formula-
#
# 𝑍=𝑋−𝜇/𝜎
#
# Where:
#
# 𝑋 = individual data point
#
# 𝜇 = population mean
#
# 𝜎 = population standard deviation
#
# b. Standardizes Different Distributions
# By converting raw scores into Z-scores, all values are put on the same standard normal scale (mean = 0, standard deviation = 1).
#
# This removes the influence of different units, scales, or spreads.
#
# c. Makes Cross-comparisons Fair
# You can compare scores from:
#
# Different exams (e.g., SAT vs ACT)
#
# Different years
#
# Different groups or measurements with different scales
#
# d. Used in Performance Rankings
#
# In business, sports, and academics, Z-scores help identify top performers or outliers across different contexts.
#
# e.  Interpreting Relative Position
#
# Z-scores help determine how unusual or typical a value is, regardless of the original distribution.
#
# 21. What are the assumptions for applying the Central Limit Theorem?
# --> The Central Limit Theorem (CLT) is a foundational concept in statistics that allows us to approximate the sampling distribution of the sample mean as normal, even if the population itself is not normally distributed — but only under certain assumptions.
#
# a. Random Sampling
#
# The data must be collected using a process of random sampling.
#
# This ensures each observation is independent and unbiased.
#
# b. Independence of Observations
#
# Each sample observation must be independent of others.
#
# For example, one person's height in a survey should not affect another’s.
#
# c. Sample Size
#
# The sample size should be sufficiently large:
#
# Rule of thumb: 𝑛≥30
#
# n≥30 is often considered adequate.
#
# For populations that are highly skewed or not normal, a larger sample may be needed.
#
# If the population is already normal, CLT applies even for small 𝑛
#
#
# d. Finite Population Variance
# The population from which the sample is drawn should have a finite variance.
#
# Extreme variability or infinite variance would violate CLT assumptions.
#
# 22. What is the concept of expected value in a probability distribution?
# --> The expected value (also called the mean or mathematical expectation) of a random variable is the long-run average outcome if an experiment is repeated many times. It represents the center or average of a probability distribution.
#
# The expected value is the weighted average of all possible outcomes, where each outcome is multiplied by its probability.
#
# 23. How does a probability distribution relate to the expected outcome of a random variable?
# --> A probability distribution and the expected outcome (expected value) of a random variable are closely connected. The expected value is calculated from the probability distribution and gives the long-run average or central value you can expect when a random experiment is repeated many times.
#
# a. Probability Distribution Defines All Possible Outcomes
#
# A probability distribution shows all the possible values a random variable can take and the probabilities associated with those values.
#
# It provides the structure for calculating the expected value.
#
# b. Expected Value Is the Weighted Average
#
# The expected outcome is computed by weighing each value of the random variable by its probability.
#
# This weighting ensures that more likely outcomes influence the average more than unlikely ones.
#
# c. Interpretation of Expected Value
#
# It's the average result if the random process (defined by the distribution) is repeated infinitely many times.
#
# Not necessarily a value the variable can actually take, but represents the center of gravity of the distribution.

# %%
# Write a Python program to generate a random variable and display its value

import random

random_value = random.randint(1, 6)

print("Random value (dice roll):", random_value)
# Out:
# Random value (dice roll): 4

# %%
# Generate a discrete uniform distribution using Python and plot the probability mass function (PMF)

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

low = 1
high = 7
dist = randint(low, high)

x = np.arange(low, high)

pmf_values = dist.pmf(x)

plt.figure(figsize=(8, 5))
# Removing 'use_line_collection=True' for compatibility with older Matplotlib versions
plt.stem(x, pmf_values)
plt.title('PMF of Discrete Uniform Distribution (1 to 6)')
plt.xlabel('Value')
plt.ylabel('Probability')
plt.ylim(0, 1)
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
# Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution

def bernoulli_pdf(x, p):
    """
    Calculate the PDF (PMF) of a Bernoulli distribution.

    Parameters:
    - x: The outcome (0 or 1)
    - p: The probability of success (P(X=1)), 0 <= p <= 1

    Returns:
    - Probability of observing x
    """
    if x not in (0, 1):
        raise ValueError("x must be 0 or 1 for a Bernoulli distribution.")
    if not (0 <= p <= 1):
        raise ValueError("p must be between 0 and 1.")

    return p if x == 1 else 1 - p
print("P(X=1) when p=0.7:", bernoulli_pdf(1, 0.7))
print("P(X=0) when p=0.7:", bernoulli_pdf(0, 0.7))
# Out:
# P(X=1) when p=0.7: 0.7
# P(X=0) when p=0.7: 0.30000000000000004

# %%
# Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

n = 10
p = 0.5
size = 10000

samples = np.random.binomial(n, p, size=size)

plt.figure(figsize=(8, 5))
plt.hist(samples, bins=np.arange(0, n+2) - 0.5, density=True, alpha=0.6, color='skyblue', edgecolor='black', label='Simulated Data')

x = np.arange(0, n+1)
pmf_values = binom.pmf(x, n, p)
plt.plot(x, pmf_values, 'o-', color='red', label='Theoretical PMF')

plt.title(f'Binomial Distribution (n={n}, p={p})')
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.xticks(x)
plt.legend()
plt.grid(alpha=0.3)

plt.show()

# %%
# Create a Poisson distribution and visualize it using Python

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

lambda_ = 4
size = 10000

samples = np.random.poisson(lam=lambda_, size=size)

x = np.arange(0, np.max(samples) + 1)

pmf_values = poisson.pmf(x, mu=lambda_)

plt.figure(figsize=(8, 5))
plt.hist(samples, bins=np.arange(0, np.max(samples)+1)-0.5, density=True,
         alpha=0.6, color='lightgreen', edgecolor='black', label='Simulated Data')

plt.plot(x, pmf_values, 'o-', color='darkgreen', label='Theoretical PMF')

# %%
# Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

low = 1
high = 7

dist = randint(low, high)

x = np.arange(low, high)

# Calculate the CDF values
cdf_values = dist.cdf(x)

# Plot the CDF
plt.figure(figsize=(8, 5))
plt.step(x, cdf_values, where='post', label='CDF', color='blue')
plt.scatter(x, cdf_values, color='blue')

# Add labels and title
plt.title('CDF of Discrete Uniform Distribution (1 to 6)')
plt.xlabel('Value')
plt.ylabel('Cumulative Probability')
plt.grid(True, linestyle='--', alpha=0.6)
plt.xticks(x)
plt.yticks(np.linspace(0, 1, high - low + 1))
plt.ylim(0, 1.1)
plt.legend()

plt.show()

# %%
#  Generate a continuous uniform distribution using NumPy and visualize it

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import uniform

a = 0
b = 1
size = 10000

samples = np.random.uniform(low=a, high=b, size=size)

# Create a histogram of the samples
plt.figure(figsize=(8, 5))
plt.hist(samples, bins=30, density=True, alpha=0.6, color='skyblue', edgecolor='black', label='Simulated Data')

# Plot the theoretical PDF
x = np.linspace(a, b, 1000)
pdf = uniform.pdf(x, loc=a, scale=b - a)
plt.plot(x, pdf, 'r--', label='Theoretical PDF', linewidth=2)

# Add labels and title
plt.title(f'Continuous Uniform Distribution U({a}, {b})')
plt.xlabel('Value')
plt.ylabel('Density')
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()

plt.show()

# %%
# Simulate data from a normal distribution and plot its histogram

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

mu = 0
sigma = 1
size = 10000

samples = np.random.normal(loc=mu, scale=sigma, size=size)

plt.figure(figsize=(8, 5))
count, bins, ignored = plt.hist(samples, bins=30, density=True, alpha=0.6,
                                 color='lightblue', edgecolor='black', label='Simulated Data')

x = np.linspace(mu - 4*sigma, mu + 4*sigma, 1000)
pdf = norm.pdf(x, mu, sigma)
plt.plot(x, pdf, 'r-', linewidth=2, label='Theoretical PDF')

plt.title(f'Normal Distribution (μ={mu}, σ={sigma})')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)

plt.show()

# %%
# Write a Python function to calculate Z-scores from a dataset and plot them

import numpy as np
import matplotlib.pyplot as plt

def calculate_and_plot_z_scores(data):
    """
    Calculate and plot Z-scores of a given dataset.

    Parameters:
    - data: list or NumPy array of numerical values

    Returns:
    - z_scores: NumPy array of Z-scores
    """
    data = np.array(data)
    mean = np.mean(data)
    std = np.std(data)

    if std == 0:
        raise ValueError("Standard deviation is zero; Z-scores cannot be computed.")

    z_scores = (data - mean) / std

    # Plot Z-scores
    plt.figure(figsize=(8, 5))
    plt.plot(z_scores, marker='o', linestyle='-', color='purple')
    plt.axhline(y=0, color='gray', linestyle='--', linewidth=1)
    plt.axhline(y=1, color='green', linestyle='--', linewidth=1, label='±1σ')
    plt.axhline(y=-1, color='green', linestyle='--', linewidth=1)
    plt.axhline(y=2, color='orange', linestyle='--', linewidth=1, label='±2σ')
    plt.axhline(y=-2, color='orange', linestyle='--', linewidth=1)
    plt.title('Z-scores of the Dataset')
    plt.xlabel('Data Index')
    plt.ylabel('Z-score')
    plt.grid(True, alpha=0.3)
    plt.legend()
    plt.show()

    return z_scores

data = [10, 12, 13, 15, 18, 20, 25, 30]

z = calculate_and_plot_z_scores(data)
print("Z-scores:", z)
# Out:
# Z-scores: [-1.2245135  -0.91352595 -0.75803217 -0.44704461  0.01943672  0.33042428
#   1.10789317  1.88536206]

# %%
# Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution

import numpy as np
import matplotlib.pyplot as plt

lambda_param = 1.0
sample_size = 30
num_samples = 1000

sample_means = []

for _ in range(num_samples):
    sample = np.random.exponential(scale=1/lambda_param, size=sample_size)
    sample_mean = np.mean(sample)
    sample_means.append(sample_mean)

plt.figure(figsize=(8, 5))
plt.hist(sample_means, bins=30, density=True, color='skyblue', edgecolor='black', alpha=0.7)
plt.title(f'Central Limit Theorem Demonstration\n(Sample Size = {sample_size}, Samples = {num_samples})')
plt.xlabel('Sample Mean')
plt.ylabel('Density')
plt.grid(alpha=0.3)
plt.show()

# %%
#  Simulate multiple samples from a normal distribution and verify the Central Limit Theorem

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parameters of the normal distribution
mu = 50          # Population mean
sigma = 10       # Population standard deviation
sample_size = 30 # Number of observations per sample
num_samples = 1000  # Number of samples to simulate

# Simulate sample means
sample_means = []

for _ in range(num_samples):
    sample = np.random.normal(loc=mu, scale=sigma, size=sample_size)
    sample_mean = np.mean(sample)
    sample_means.append(sample_mean)

# Convert to NumPy array
sample_means = np.array(sample_means)

# Plot histogram of sample means
plt.figure(figsize=(8, 5))
plt.hist(sample_means, bins=30, density=True, color='lightcoral', edgecolor='black', alpha=0.7, label='Sample Means')

# Overlay the theoretical normal distribution (CLT expected result)
x = np.linspace(min(sample_means), max(sample_means), 1000)
pdf = norm.pdf(x, loc=mu, scale=sigma / np.sqrt(sample_size))
plt.plot(x, pdf, 'k--', linewidth=2, label='Expected Normal (CLT)')

# Add labels and legend
plt.title(f'CLT with Normal Distribution\nSample Size = {sample_size}, Samples = {num_samples}')
plt.xlabel('Sample Mean')
plt.ylabel('Density')
plt.grid(alpha=0.3)
plt.legend()

plt.show()

# %%
# Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1)

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_standard_normal_distribution():
    """
    Calculates and plots the PDF of the standard normal distribution.
    """
    # Define x values around the mean (0 ± 4σ)
    x = np.linspace(-4, 4, 1000)

    # Compute PDF values for standard normal distribution
    pdf = norm.pdf(x, loc=0, scale=1)

    # Plot the PDF
    plt.figure(figsize=(8, 5))
    plt.plot(x, pdf, label='Standard Normal PDF', color='blue', linewidth=2)
    plt.title('Standard Normal Distribution (μ = 0, σ = 1)')
    plt.xlabel('Z-score')
    plt.ylabel('Probability Density')
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.axvline(x=0, color='black', linestyle='--', alpha=0.8)
    plt.legend()
    plt.show()

plot_standard_normal_distribution()

# %%
#  Generate random variables and calculate their corresponding probabilities using the binomial distribution

import numpy as np
from scipy.stats import binom
import matplotlib.pyplot as plt

n = 10       # number of trials
p = 0.5      # probability of success
size = 1000  # number of samples

samples = np.random.binomial(n=n, p=p, size=size)

unique_values, counts = np.unique(samples, return_counts=True)

pmf_values = binom.pmf(unique_values, n, p)

empirical_probs = counts / size

plt.figure(figsize=(8, 5))
plt.bar(unique_values - 0.2, empirical_probs, width=0.4, label='Empirical Probabilities', color='skyblue')
plt.bar(unique_values + 0.2, pmf_values, width=0.4, label='Theoretical PMF', color='orange')
plt.title(f'Binomial Distribution: n={n}, p={p}')
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.xticks(unique_values)
plt.grid(alpha=0.3)
plt.legend()
plt.show()

for x, emp, theo in zip(unique_values, empirical_probs, pmf_values):
    print(f"P(X={x}) -> Empirical: {emp:.3f}, Theoretical: {theo:.3f}")
# Out:
# P(X=0) -> Empirical: 0.003, Theoretical: 0.001
# P(X=1) -> Empirical: 0.007, Theoretical: 0.010
# P(X=2) -> Empirical: 0.035, Theoretical: 0.044
# P(X=3) -> Empirical: 0.136, Theoretical: 0.117
# P(X=4) -> Empirical: 0.193, Theoretical: 0.205
# P(X=5) -> Empirical: 0.256, Theoretical: 0.246
# P(X=6) -> Empirical: 0.174, Theoretical: 0.205
# P(X=7) -> Empirical: 0.130, Theoretical: 0.117
# P(X=8) -> Empirical: 0.054, Theoretical: 0.044
# P(X=9) -> Empirical: 0.012, Theoretical: 0.010

# %%
# Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def calculate_and_plot_z_score(x, mean, std_dev):
    z = (x - mean) / std_dev
    print(f"Z-score for X = {x} (mean = {mean}, std = {std_dev}): {z:.3f}")

    x_vals = np.linspace(-4, 4, 1000)
    pdf_vals = norm.pdf(x_vals, loc=0, scale=1)

    plt.figure(figsize=(10, 5))
    plt.plot(x_vals, pdf_vals, label='Standard Normal Distribution', color='blue')

    plt.axvline(z, color='red', linestyle='--', linewidth=2, label=f'Z = {z:.2f}')

    x_fill = np.linspace(-4, z, 1000)
    plt.fill_between(x_fill, norm.pdf(x_fill), alpha=0.3, color='red')

    plt.title('Z-score Visualization on Standard Normal Distribution')
    plt.xlabel('Z-score')
    plt.ylabel('Probability Density')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.4)
    plt.show()

    return z

calculate_and_plot_z_score(x=75, mean=70, std_dev=10)
# Out:
# Z-score for X = 75 (mean = 70, std = 10): 0.500
# 0.5

# %%
# Implement hypothesis testing using Z-statistics for a sample dataset

import numpy as np
from scipy.stats import norm

def z_test(sample_data, mu_0, sigma, alpha=0.05):
    """
    Perform a Z-test for population mean.

    Parameters:
    - sample_data: list or array of sample observations
    - mu_0: hypothesized population mean (under H0)
    - sigma: known population standard deviation
    - alpha: significance level (default 0.05)

    Returns:
    - Z-score
    - p-value
    - test result
    """
    sample_data = np.array(sample_data)
    n = len(sample_data)
    sample_mean = np.mean(sample_data)

    # Calculate Z-score
    z = (sample_mean - mu_0) / (sigma / np.sqrt(n))

    # Two-tailed test p-value
    p_value = 2 * (1 - norm.cdf(abs(z)))

    print(f"Sample Mean = {sample_mean:.2f}, Hypothesized Mean = {mu_0}")
    print(f"Z-score = {z:.3f}")
    print(f"P-value = {p_value:.4f}")

    if p_value < alpha:
        print("Reject the null hypothesis (H0).")
    else:
        print("Fail to reject the null hypothesis (H0).")

    return z, p_value

sample = [68, 72, 71, 69, 70, 74, 73, 67, 70, 72]

z_test(sample_data=sample, mu_0=70, sigma=3, alpha=0.05)
# Out:
# Sample Mean = 70.60, Hypothesized Mean = 70
# Z-score = 0.632
# P-value = 0.5271
# Fail to reject the null hypothesis (H0).
# (np.float64(0.6324555320336699), np.float64(0.5270892568655419))

# %%
# Create a confidence interval for a dataset using Python and interpret the result

import numpy as np
from scipy import stats

def confidence_interval(data, confidence=0.95):
    """
    Calculate and interpret a confidence interval for the mean.

    Parameters:
    - data: list or NumPy array of sample data
    - confidence: confidence level (default 95%)

    Returns:
    - (lower bound, upper bound) of the confidence interval
    """
    data = np.array(data)
    n = len(data)
    mean = np.mean(data)
    std_err = stats.sem(data)  # Standard error of the mean
    t_critical = stats.t.ppf((1 + confidence) / 2, df=n-1)  # Two-tailed t-critical value

    margin_of_error = t_critical * std_err
    lower = mean - margin_of_error
    upper = mean + margin_of_error

    print(f"Sample Mean = {mean:.2f}")
    print(f"{int(confidence * 100)}% Confidence Interval: ({lower:.2f}, {upper:.2f})")
    print(f"We are {int(confidence * 100)}% confident the true population mean lies between {lower:.2f} and {upper:.2f}.")

    return lower, upper

data = [68, 72, 71, 69, 70, 74, 73, 67, 70, 72]

confidence_interval(data)
# Out:
# Sample Mean = 70.60
# 95% Confidence Interval: (69.01, 72.19)
# We are 95% confident the true population mean lies between 69.01 and 72.19.
# (np.float64(69.0111130265089), np.float64(72.1888869734911))

# %%
#  Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean

import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

np.random.seed(42)  # for reproducibility
data = np.random.normal(loc=50, scale=10, size=100)

confidence = 0.95
n = len(data)
mean = np.mean(data)
std_err = stats.sem(data)  # standard error of the mean
t_critical = stats.t.ppf((1 + confidence) / 2, df=n-1)

margin_of_error = t_critical * std_err
lower = mean - margin_of_error
upper = mean + margin_of_error

print(f"Sample Mean = {mean:.2f}")
print(f"95% Confidence Interval = ({lower:.2f}, {upper:.2f})")
print(f"We are 95% confident the true population mean lies between {lower:.2f} and {upper:.2f}.")

plt.figure(figsize=(8, 5))
plt.hist(data, bins=15, color='skyblue', edgecolor='black', alpha=0.7)
plt.axvline(mean, color='red', linestyle='--', label='Sample Mean')
plt.axvline(lower, color='green', linestyle='--', label='Lower CI Bound')
plt.axvline(upper, color='green', linestyle='--', label='Upper CI Bound')
plt.title('Histogram of Sample Data with Confidence Interval')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()
plt.grid(alpha=0.3)
plt.show()
# Out:
# Sample Mean = 48.96
# 95% Confidence Interval = (47.16, 50.76)
# We are 95% confident the true population mean lies between 47.16 and 50.76.

# %%
# Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_normal_pdf(mean=0, std_dev=1):
    """
    Plot the PDF of a normal distribution with given mean and standard deviation.
    """
    # Generate x values
    x = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 1000)

    # Calculate the PDF values using scipy
    pdf = norm.pdf(x, loc=mean, scale=std_dev)

    # Plot
    plt.figure(figsize=(8, 5))
    plt.plot(x, pdf, color='navy', linewidth=2, label=f'Normal PDF (μ={mean}, σ={std_dev})')
    plt.title('Normal Distribution - Probability Density Function')
    plt.xlabel('x')
    plt.ylabel('PDF')
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.axvline(mean, color='red', linestyle='--', label='Mean (μ)')
    plt.legend()
    plt.show()

plot_normal_pdf(mean=50, std_dev=10)

# %%
#  Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

def plot_poisson_cdf(lmbda, max_x=20):
    """
    Calculates and plots the CDF of a Poisson distribution with parameter lambda.
    """
    # x values (discrete range)
    x = np.arange(0, max_x + 1)

    # CDF values
    cdf_values = poisson.cdf(x, mu=lmbda)

    # Plotting
    plt.figure(figsize=(8, 5))
    plt.step(x, cdf_values, where='post', label=f'Poisson CDF (λ={lmbda})', color='darkorange')
    plt.title('Poisson Distribution - Cumulative Distribution Function (CDF)')
    plt.xlabel('Number of Events (k)')
    plt.ylabel('Cumulative Probability')
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.xticks(x)
    plt.ylim(0, 1.05)
    plt.legend()
    plt.show()

    k = 5
    prob = poisson.cdf(k, mu=lmbda)
    print(f"P(X ≤ {k}) = {prob:.4f}")
    print(f"Interpretation: There is a {prob*100:.2f}% chance that there will be {k} or fewer events.")

plot_poisson_cdf(lmbda=4, max_x=15)
# Out:
# P(X ≤ 5) = 0.7851
# Interpretation: There is a 78.51% chance that there will be 5 or fewer events.

# %%
#  Simulate a random variable using a continuous uniform distribution and calculate its expected value

import numpy as np

def simulate_uniform_continuous(a, b, size=1000):
    # Step 1: Simulate random variable from Uniform(a, b)
    samples = np.random.uniform(a, b, size)

    # Step 2: Theoretical expected value
    expected_value_theoretical = (a + b) / 2

    # Step 3: Empirical mean from simulated data
    expected_value_empirical = np.mean(samples)

    print(f"Uniform Distribution U({a}, {b})")
    print(f"Theoretical Expected Value: {expected_value_theoretical:.4f}")
    print(f"Empirical Mean from {size} samples: {expected_value_empirical:.4f}")

    return samples

simulate_uniform_continuous(a=10, b=20, size=100)
# Out:
# Uniform Distribution U(10, 20)
# Theoretical Expected Value: 15.0000
# Empirical Mean from 100 samples: 15.4027
# array([17.23420114, 14.95875735, 10.81046216, 12.20183202, 16.83258764,
#        10.76130859, 18.51206914, 14.95146527, 14.80586577, 15.92407785,
#        18.24680966, 13.47809208, 16.78016153, 15.65731964, 12.6702827 ,
#        18.78629986, 17.97426022, 16.58451835, 18.50581729, 18.67294201,
#        17.08362977, 18.37013328, 16.97471462, 16.80140772, 16.18611378,
#        17.5271664 , 11.58605105, 18.80870759, 18.71843528, 10.29247283,
#        18.25816751, 11.28869867, 13.35118854, 17.43508256, 11.60759896,
#        18.17967024, 18.32134178, 15.07467734, 10.06385872, 12.87038133,
#        16.16926918, 19.81186178, 16.31813527, 12.59803581, 16.34005703,
#        15.3998538 , 17.79845395, 11.06980639, 17.61027903, 15.41266579,
#        19.62992004, 13.41872166, 16.32621893, 19.32028106, 11.02509728,
# ...

# %%
# Write a Python program to compare the standard deviations of two datasets and visualize the difference

import numpy as np
import matplotlib.pyplot as plt

def compare_std(data1, data2, label1='Dataset 1', label2='Dataset 2'):
    # Calculate standard deviations
    std1 = np.std(data1, ddof=1)
    std2 = np.std(data2, ddof=1)

    print(f"{label1} - Standard Deviation: {std1:.2f}")
    print(f"{label2} - Standard Deviation: {std2:.2f}")

    # Plot histograms
    plt.figure(figsize=(10, 5))
    plt.hist(data1, bins=15, alpha=0.6, label=f'{label1} (std = {std1:.2f})', color='skyblue', edgecolor='black')
    plt.hist(data2, bins=15, alpha=0.6, label=f'{label2} (std = {std2:.2f})', color='salmon', edgecolor='black')

    plt.title('Comparison of Standard Deviations')
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.show()

np.random.seed(42)
data_a = np.random.normal(loc=50, scale=5, size=1000)   # smaller spread
data_b = np.random.normal(loc=50, scale=15, size=1000)  # larger spread

compare_std(data_a, data_b, label1='Low Variability', label2='High Variability')
# Out:
# Low Variability - Standard Deviation: 4.90
# High Variability - Standard Deviation: 14.96

# %%
# Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution

import numpy as np

def calculate_range_and_iqr(mean=0, std_dev=1, size=1000):
    data = np.random.normal(loc=mean, scale=std_dev, size=size)

    data_range = np.max(data) - np.min(data)

    q1 = np.percentile(data, 25)
    q3 = np.percentile(data, 75)
    iqr = q3 - q1

    print(f"Generated Normal Distribution: mean = {mean}, std = {std_dev}, n = {size}")
    print(f"Range = {data_range:.2f}")
    print(f"IQR (Interquartile Range) = {iqr:.2f}")
    print(f"Q1 = {q1:.2f}, Q3 = {q3:.2f}")

    return data_range, iqr

calculate_range_and_iqr(mean=50, std_dev=10, size=1000)
# Out:
# Generated Normal Distribution: mean = 50, std = 10, n = 1000
# Range = 69.46
# IQR (Interquartile Range) = 13.09
# Q1 = 43.52, Q3 = 56.61
# (np.float64(69.45749862257152), np.float64(13.089149281446446))

# %%
# Implement Z-score normalization on a dataset and visualize its transformation

import numpy as np
import matplotlib.pyplot as plt

def z_score_normalization(data):
    mean = np.mean(data)
    std = np.std(data)
    z_scores = (data - mean) / std
    return z_scores

def visualize_normalization():
    np.random.seed(0)
    data = np.random.normal(loc=50, scale=10, size=1000)

    z_data = z_score_normalization(data)

    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.hist(data, bins=30, color='skyblue', edgecolor='black')
    plt.title('Original Data')
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.axvline(np.mean(data), color='red', linestyle='--', label='Mean')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.hist(z_data, bins=30, color='lightgreen', edgecolor='black')
    plt.title('Z-score Normalized Data')
    plt.xlabel('Z-score')
    plt.ylabel('Frequency')
    plt.axvline(np.mean(z_data), color='red', linestyle='--', label='Mean = 0')
    plt.legend()

    plt.tight_layout()
    plt.show()

    print(f"Original Mean: {np.mean(data):.2f}, Std Dev: {np.std(data):.2f}")
    print(f"Z-Score Mean: {np.mean(z_data):.2f}, Std Dev: {np.std(z_data):.2f}")

visualize_normalization()
# Out:
# Original Mean: 49.55, Std Dev: 9.87
# Z-Score Mean: 0.00, Std Dev: 1.00

# %%
# Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution

import numpy as np
from scipy.stats import skew, kurtosis

def analyze_normal_distribution(mean=0, std_dev=1, size=1000):
    data = np.random.normal(loc=mean, scale=std_dev, size=size)

    skewness = skew(data)
    excess_kurtosis = kurtosis(data)  # default is Fisher's definition (excess)

    print(f"Generated Normal Distribution N({mean}, {std_dev**2}) with {size} samples")
    print(f"Skewness: {skewness:.4f} (should be ~0 for normal)")
    print(f"Excess Kurtosis: {excess_kurtosis:.4f} (should be ~0 for normal)")

    return skewness, excess_kurtosis

analyze_normal_distribution(mean=50, std_dev=10, size=1000)
# Out:
# Generated Normal Distribution N(50, 100) with 1000 samples
# Skewness: 0.0556 (should be ~0 for normal)
# Excess Kurtosis: -0.1075 (should be ~0 for normal)
# (np.float64(0.055647222974737946), np.float64(-0.10745402808912496))
